# %% [markdown]
# 1.外部散点图

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 读取三个CSV文件

df4 = pd.read_csv('fig2.9/theory_gamma8_beta1.05.csv')
df5 = pd.read_csv('fig2.9/theory_recover_gamma8_beta1.25.csv')

# 创建散点图
plt.figure(figsize=(10, 8))  # 设置图形大小

# 绘制每个数据集的散点图，使用不同颜色和标签

plt.plot(df4.iloc[:, 1], df4.iloc[:, 2], color='#666666')
plt.plot(df5.iloc[:, 1], df5.iloc[:, 2], color='#a9a9a9')

# 设置X轴和Y轴范围
x_min, x_max = -1, 160
y_min, y_max = -1, 50
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

# 计算中位数刻度（这里用范围的中值）
x_mid = (0 + x_max) / 2  # x 轴中值
y_mid = (0 + y_max) / 2  # y 轴中值

# 设置 x 轴和 y 轴刻度为最小值、中值和最大值
plt.xticks([0, x_mid, x_max], fontsize=30)
plt.yticks([0, y_mid, y_max], fontsize=30)

# 保存为 PDF 文件
plt.savefig('fig2/fig2.9-out.png', format='png', bbox_inches='tight')

# 显示图形
plt.show()

# %% [markdown]
# 2.内部inset

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 读取三个CSV文件

df4 = pd.read_csv('fig2.9/theory_gamma8_beta1.05.csv')
df5 = pd.read_csv('fig2.9/theory_recover_gamma8_beta1.25.csv')

# 创建散点图
plt.figure(figsize=(10, 8))  # 设置图形大小

# 绘制每个数据集的散点图，使用不同颜色和标签

plt.plot(df4.iloc[:, 1], df4.iloc[:, 2], color='#666666')
plt.plot(df5.iloc[:, 1], df5.iloc[:, 2], color='#a9a9a9')

# 设置坐标轴为对数刻度
plt.xscale('log')
plt.yscale('log')

plt.xlim(0.9, 160)

# 增大刻度值的字体大小
plt.tick_params(axis='both', labelsize=30)  # 'both' 表示 x 和 y 轴，labelsize 设置字体大小

# 保存为 PDF 文件
plt.savefig('fig2/fig2.9-in.pdf', format='pdf', bbox_inches='tight')

# 显示图形
plt.show()
